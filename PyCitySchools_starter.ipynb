# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load
school_data_to_load = "PyCitySchools/Resources/schools_complete.csv"
student_data_to_load = "PyCitySchools/Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
#Printing out merged data head
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
#Total number of schools
schoolnames = school_data_complete["school_name"].unique()
schoolnamecount=len(schoolnames)
schoolnamecount
# Out:
# 15

# %%
#Total number of students
studentcount = len(school_data_complete["Student ID"])
studentcount
# Out:
# 39170

# %%
#Total budget
totalbudget = school_data["budget"].sum()
totalbudget
# Out:
# 24649428

# %%
#Average math score
avg_mathscore = school_data_complete["math_score"].mean()
avg_mathscore
# Out:
# 78.98537145774827

# %%
#Average reading score
avg_readingscore = school_data_complete["reading_score"].mean()
avg_readingscore
# Out:
# 81.87784018381414

# %%
#Percent students with passing math score (>=70)
passingmath = school_data_complete.loc[school_data_complete["math_score"] >= 70]
percentpassingmath = (len(passingmath)/studentcount)*100
percentpassingmath
# Out:
# 74.9808526933878

# %%
#Percent students with passing reading score (>=70)
#Percent students with passing math score (>=70)
passingreading = school_data_complete.loc[school_data_complete["reading_score"] >= 70]
percentpassingreading = (len(passingreading)/studentcount)*100
percentpassingreading
# Out:
# 85.80546336482001

# %%
#Percent students with passing math AND reading score (% Overall Passing)
passingboth = school_data_complete.loc[(school_data_complete["reading_score"] >= 70) & (school_data_complete["math_score"] >= 70)]
percentpassingboth = (len(passingboth)/studentcount)*100
percentpassingboth
# Out:
# 65.17232575950983

# %%
#Dataframe to hold above results
districtsummary_df = pd.DataFrame(
    {"Total Schools": [schoolnamecount],
    "Total Students": [studentcount],
    "Total Budget": [totalbudget],
    "Average Math Score": [avg_mathscore],
    "Average Reading Score": [avg_readingscore],
    "% Passing Math": [percentpassingmath],
    "% Passing Reading": [percentpassingreading],
    "% Overall Passing": [percentpassingboth]
})

districtsummary_df
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          65.172326

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
#School type
schooltype = school_data_complete.groupby("school_name")['type'].unique()
schooltype
# Out:
# school_name
# Bailey High School       [District]
# Cabrera High School       [Charter]
# Figueroa High School     [District]
# Ford High School         [District]
# Griffin High School       [Charter]
# Hernandez High School    [District]
# Holden High School        [Charter]
# Huang High School        [District]
# Johnson High School      [District]
# Pena High School          [Charter]
# Rodriguez High School    [District]
# Shelton High School       [Charter]
# Thomas High School        [Charter]
# Wilson High School        [Charter]
# Wright High School        [Charter]
# Name: type, dtype: object

# %%
#Total Students
totalstudents = school_data_complete.groupby('school_name')['Student ID'].nunique()
totalstudents
# Out:
# school_name
# Bailey High School       4976
# Cabrera High School      1858
# Figueroa High School     2949
# Ford High School         2739
# Griffin High School      1468
# Hernandez High School    4635
# Holden High School        427
# Huang High School        2917
# Johnson High School      4761
# Pena High School          962
# Rodriguez High School    3999
# Shelton High School      1761
# Thomas High School       1635
# Wilson High School       2283
# Wright High School       1800
# Name: Student ID, dtype: int64

# %%
#Total School Budget
budget = school_data_complete.groupby('school_name')['budget'].sum()
totalschoolbudget = budget/totalstudents
totalschoolbudget
# Out:
# school_name
# Bailey High School       3124928.0
# Cabrera High School      1081356.0
# Figueroa High School     1884411.0
# Ford High School         1763916.0
# Griffin High School       917500.0
# Hernandez High School    3022020.0
# Holden High School        248087.0
# Huang High School        1910635.0
# Johnson High School      3094650.0
# Pena High School          585858.0
# Rodriguez High School    2547363.0
# Shelton High School      1056600.0
# Thomas High School       1043130.0
# Wilson High School       1319574.0
# Wright High School       1049400.0
# dtype: float64

# %%
#Per Student Budget
studentbudget = totalschoolbudget/totalstudents
studentbudget
# Out:
# school_name
# Bailey High School       628.0
# Cabrera High School      582.0
# Figueroa High School     639.0
# Ford High School         644.0
# Griffin High School      625.0
# Hernandez High School    652.0
# Holden High School       581.0
# Huang High School        655.0
# Johnson High School      650.0
# Pena High School         609.0
# Rodriguez High School    637.0
# Shelton High School      600.0
# Thomas High School       638.0
# Wilson High School       578.0
# Wright High School       583.0
# dtype: float64

# %%
#Average Math Score
avgmathscore = school_data_complete.groupby('school_name')['math_score'].mean()
avgmathscore
# Out:
# school_name
# Bailey High School       77.048432
# Cabrera High School      83.061895
# Figueroa High School     76.711767
# Ford High School         77.102592
# Griffin High School      83.351499
# Hernandez High School    77.289752
# Holden High School       83.803279
# Huang High School        76.629414
# Johnson High School      77.072464
# Pena High School         83.839917
# Rodriguez High School    76.842711
# Shelton High School      83.359455
# Thomas High School       83.418349
# Wilson High School       83.274201
# Wright High School       83.682222
# Name: math_score, dtype: float64

# %%
#Average Reading Score
avgreadingscore = school_data_complete.groupby('school_name')['reading_score'].mean()
avgreadingscore
# Out:
# school_name
# Bailey High School       81.033963
# Cabrera High School      83.975780
# Figueroa High School     81.158020
# Ford High School         80.746258
# Griffin High School      83.816757
# Hernandez High School    80.934412
# Holden High School       83.814988
# Huang High School        81.182722
# Johnson High School      80.966394
# Pena High School         84.044699
# Rodriguez High School    80.744686
# Shelton High School      83.725724
# Thomas High School       83.848930
# Wilson High School       83.989488
# Wright High School       83.955000
# Name: reading_score, dtype: float64

# %%
#Calculating percentage math pass rate by school
schoolpassmath = school_data_complete[school_data_complete["math_score"] >= 70].groupby("school_name")["math_score"].count()/totalstudents*100
schoolpassmath
# Out:
# school_name
# Bailey High School       66.680064
# Cabrera High School      94.133477
# Figueroa High School     65.988471
# Ford High School         68.309602
# Griffin High School      93.392371
# Hernandez High School    66.752967
# Holden High School       92.505855
# Huang High School        65.683922
# Johnson High School      66.057551
# Pena High School         94.594595
# Rodriguez High School    66.366592
# Shelton High School      93.867121
# Thomas High School       93.272171
# Wilson High School       93.867718
# Wright High School       93.333333
# dtype: float64

# %%
#% Passing Reading
schoolpassread = school_data_complete[school_data_complete["reading_score"] >= 70].groupby("school_name")["reading_score"].count()/totalstudents*100
schoolpassread
# Out:
# school_name
# Bailey High School       81.933280
# Cabrera High School      97.039828
# Figueroa High School     80.739234
# Ford High School         79.299014
# Griffin High School      97.138965
# Hernandez High School    80.862999
# Holden High School       96.252927
# Huang High School        81.316421
# Johnson High School      81.222432
# Pena High School         95.945946
# Rodriguez High School    80.220055
# Shelton High School      95.854628
# Thomas High School       97.308869
# Wilson High School       96.539641
# Wright High School       96.611111
# dtype: float64

# %%
#% Overall Passing
schoolpassboth = school_data_complete[(school_data_complete["reading_score"] >= 70) & (school_data_complete["math_score"] >= 70)].groupby("school_name")["student_name"].count()/totalstudents*100
schoolpassboth
# Out:
# school_name
# Bailey High School       54.642283
# Cabrera High School      91.334769
# Figueroa High School     53.204476
# Ford High School         54.289887
# Griffin High School      90.599455
# Hernandez High School    53.527508
# Holden High School       89.227166
# Huang High School        53.513884
# Johnson High School      53.539172
# Pena High School         90.540541
# Rodriguez High School    52.988247
# Shelton High School      89.892107
# Thomas High School       90.948012
# Wilson High School       90.582567
# Wright High School       90.333333
# dtype: float64

# %%
#Merging series
merge_df = pd.merge(schooltype, totalstudents, on="school_name")
merge_df
# Out:
#                              type  Student ID
# school_name
# Bailey High School     [District]        4976
# Cabrera High School     [Charter]        1858
# Figueroa High School   [District]        2949
# Ford High School       [District]        2739
# Griffin High School     [Charter]        1468
# Hernandez High School  [District]        4635
# Holden High School      [Charter]         427
# Huang High School      [District]        2917
# Johnson High School    [District]        4761
# Pena High School        [Charter]         962
# Rodriguez High School  [District]        3999
# Shelton High School     [Charter]        1761
# Thomas High School      [Charter]        1635
# Wilson High School      [Charter]        2283
# Wright High School      [Charter]        1800

# %%
merge2_df = pd.merge(merge_df, avgmathscore, on="school_name")
merge2_df
# Out:
#                              type  Student ID  math_score
# school_name
# Bailey High School     [District]        4976   77.048432
# Cabrera High School     [Charter]        1858   83.061895
# Figueroa High School   [District]        2949   76.711767
# Ford High School       [District]        2739   77.102592
# Griffin High School     [Charter]        1468   83.351499
# Hernandez High School  [District]        4635   77.289752
# Holden High School      [Charter]         427   83.803279
# Huang High School      [District]        2917   76.629414
# Johnson High School    [District]        4761   77.072464
# Pena High School        [Charter]         962   83.839917
# Rodriguez High School  [District]        3999   76.842711
# Shelton High School     [Charter]        1761   83.359455
# Thomas High School      [Charter]        1635   83.418349
# Wilson High School      [Charter]        2283   83.274201
# Wright High School      [Charter]        1800   83.682222

# %%
merge3_df = pd.merge(merge2_df, avgreadingscore, on="school_name")
merge3_df
# Out:
#                              type  Student ID  math_score  reading_score
# school_name
# Bailey High School     [District]        4976   77.048432      81.033963
# Cabrera High School     [Charter]        1858   83.061895      83.975780
# Figueroa High School   [District]        2949   76.711767      81.158020
# Ford High School       [District]        2739   77.102592      80.746258
# Griffin High School     [Charter]        1468   83.351499      83.816757
# Hernandez High School  [District]        4635   77.289752      80.934412
# Holden High School      [Charter]         427   83.803279      83.814988
# Huang High School      [District]        2917   76.629414      81.182722
# Johnson High School    [District]        4761   77.072464      80.966394
# Pena High School        [Charter]         962   83.839917      84.044699
# Rodriguez High School  [District]        3999   76.842711      80.744686
# Shelton High School     [Charter]        1761   83.359455      83.725724
# ...

# %%
#For some reason, (possibly because of division by a groupby in totalstudents variable), these dataframes will not merge with the others directly. So, created a new dataframe to hold these.
dividedbytotalstudents_df=pd.DataFrame ({"Total School Budget": totalschoolbudget,
                          "Per Student Budget": studentbudget,
                          "% Passing Math": schoolpassmath,
                          "% Passing Reading": schoolpassread,
                          "% Overall Passing": schoolpassboth
                            })

# %%
#Merging all series into single dataframe
all_df = pd.merge(merge3_df, dividedbytotalstudents_df, on="school_name")
all_df
# Out:
#                              type  Student ID  math_score  reading_score  \
# school_name
# Bailey High School     [District]        4976   77.048432      81.033963
# Cabrera High School     [Charter]        1858   83.061895      83.975780
# Figueroa High School   [District]        2949   76.711767      81.158020
# Ford High School       [District]        2739   77.102592      80.746258
# Griffin High School     [Charter]        1468   83.351499      83.816757
# Hernandez High School  [District]        4635   77.289752      80.934412
# Holden High School      [Charter]         427   83.803279      83.814988
# Huang High School      [District]        2917   76.629414      81.182722
# Johnson High School    [District]        4761   77.072464      80.966394
# Pena High School        [Charter]         962   83.839917      84.044699
# Rodriguez High School  [District]        3999   76.842711      80.744686
# Shelton High School     [Charter]        1761   83.359455      83.725724
# ...

# %%
#School Summary renamed
schoolsummary_df = all_df.rename(columns={"type":"School Type", "Student ID":"Total Students","math_score":"Average Math Score","reading_score":"Average Reading Score"})
schoolsummary_df
# Out:
#                       School Type  Total Students  Average Math Score  \
# school_name
# Bailey High School     [District]            4976           77.048432
# Cabrera High School     [Charter]            1858           83.061895
# Figueroa High School   [District]            2949           76.711767
# Ford High School       [District]            2739           77.102592
# Griffin High School     [Charter]            1468           83.351499
# Hernandez High School  [District]            4635           77.289752
# Holden High School      [Charter]             427           83.803279
# Huang High School      [District]            2917           76.629414
# Johnson High School    [District]            4761           77.072464
# Pena High School        [Charter]             962           83.839917
# Rodriguez High School  [District]            3999           76.842711
# Shelton High School     [Charter]            1761           83.359455
# ...

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
schoolsummary_df = schoolsummary_df.sort_values("% Overall Passing", ascending=False)
schoolsummary_df.head(5)
# Out:
#                     School Type  Total Students  Average Math Score  \
# school_name
# Cabrera High School   [Charter]            1858           83.061895
# Thomas High School    [Charter]            1635           83.418349
# Griffin High School   [Charter]            1468           83.351499
# Wilson High School    [Charter]            2283           83.274201
# Pena High School      [Charter]             962           83.839917
#
#                      Average Reading Score  Total School Budget  \
# school_name
# Cabrera High School              83.975780            1081356.0
# Thomas High School               83.848930            1043130.0
# Griffin High School              83.816757             917500.0
# Wilson High School               83.989488            1319574.0
# Pena High School                 84.044699             585858.0
#
#                      Per Student Budget  % Passing Math  % Passing Reading  \
# school_name
# ...

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
schoolsummary_df = schoolsummary_df.sort_values("% Overall Passing")
schoolsummary_df.head(5)
# Out:
#                       School Type  Total Students  Average Math Score  \
# school_name
# Rodriguez High School  [District]            3999           76.842711
# Figueroa High School   [District]            2949           76.711767
# Huang High School      [District]            2917           76.629414
# Hernandez High School  [District]            4635           77.289752
# Johnson High School    [District]            4761           77.072464
#
#                        Average Reading Score  Total School Budget  \
# school_name
# Rodriguez High School              80.744686            2547363.0
# Figueroa High School               81.158020            1884411.0
# Huang High School                  81.182722            1910635.0
# Hernandez High School              80.934412            3022020.0
# Johnson High School                80.966394            3094650.0
#
#                        Per Student Budget  % Passing Math  % Passing Reading  \
# school_name
# ...

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
#Combining loc to find values for grade and returning groupby school name, all while finding the average within that group
ninthmathscore = student_data.loc[school_data_complete["grade"]=="9th"].groupby("school_name")["math_score"].mean()
tenthmathscore = student_data.loc[school_data_complete["grade"]=="10th"].groupby("school_name")["math_score"].mean()
eleventhmathscore = student_data.loc[school_data_complete["grade"]=="11th"].groupby("school_name")["math_score"].mean()
twelfthmathscore = student_data.loc[school_data_complete["grade"]=="12th"].groupby("school_name")["math_score"].mean()

# %%
#merging
ninthandtenth_df = pd.merge(ninthmathscore, tenthmathscore, on="school_name")

# %%
eleandtwe_df = pd.merge(eleventhmathscore, twelfthmathscore, on="school_name")

# %%
gradesunlabeled_df = pd.merge(eleandtwe_df, ninthandtenth_df, on="school_name")

# %%
gradeslabeled_df = gradesunlabeled_df.rename(columns={"math_score_x_x":"11th", "math_score_y_x":"12th","math_score_x_y":"9th","math_score_y_y":"10th"})

# %%
mathbygrade_df=gradeslabeled_df[["9th", "10th", "11th", "12th"]]
mathbygrade_df
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# ...

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
#Combining loc to find values for grade and returning groupby school name, all while finding the average within that group
ninthreadscore = student_data.loc[school_data_complete["grade"]=="9th"].groupby("school_name")["reading_score"].mean()
tenthreadscore = student_data.loc[school_data_complete["grade"]=="10th"].groupby("school_name")["reading_score"].mean()
eleventhreadscore = student_data.loc[school_data_complete["grade"]=="11th"].groupby("school_name")["reading_score"].mean()
twelfthreadscore = student_data.loc[school_data_complete["grade"]=="12th"].groupby("school_name")["reading_score"].mean()

# %%
#merging everything
rnineandten_df = pd.merge(ninthreadscore, tenthreadscore, on="school_name")
releandtwe_df = pd.merge(eleventhreadscore, twelfthreadscore, on="school_name")
rall_df = pd.merge(rnineandten_df, releandtwe_df, on="school_name")

# %%
readlabeled_df = rall_df.rename(columns={"reading_score_x_x":"9th", "reading_score_y_x":"10th","reading_score_x_y":"11th","reading_score_y_y":"12th"})
readlabeled_df
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# ...

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
#Finding the max and min values of the dataframe to determine appropriate bins
print(all_df["Per Student Budget"].max())
print(all_df["Per Student Budget"].min())
# Out:
# 655.0
# 578.0

# %%
#Creating bins based on max/min student budget values
bins = [575,597.25,616.5,635.75,655]
#bin names
ranges = ["$575-$597.25", "$597.25-$616.5","$616.5-$635.75", "$635.75-$655"]

# %%
#Slicing the data and placing into bins
pd.cut(schoolsummary_df["Per Student Budget"], bins, labels=ranges)
# Out:
# school_name
# Rodriguez High School      $635.75-$655
# Figueroa High School       $635.75-$655
# Huang High School          $635.75-$655
# Hernandez High School      $635.75-$655
# Johnson High School        $635.75-$655
# Ford High School           $635.75-$655
# Bailey High School       $616.5-$635.75
# Holden High School         $575-$597.25
# Shelton High School      $597.25-$616.5
# Wright High School         $575-$597.25
# Pena High School         $597.25-$616.5
# Wilson High School         $575-$597.25
# Griffin High School      $616.5-$635.75
# Thomas High School         $635.75-$655
# Cabrera High School        $575-$597.25
# Name: Per Student Budget, dtype: category
# Categories (4, object): [$575-$597.25 < $597.25-$616.5 < $616.5-$635.75 < $635.75-$655]

# %%
#Creating a column for spending ranges
schoolsummary_df["Spending Ranges (Per Student)"] = pd.cut(schoolsummary_df["Per Student Budget"], bins=bins, labels=ranges)
schoolsummary_df.reset_index(drop=True,inplace=True)

# %%
#Creating series for each parameter. Need to take the average for each range of school spending!
mathscorespend = schoolsummary_df.groupby("Spending Ranges (Per Student)")["Average Math Score"].mean()
readscorespend = schoolsummary_df.groupby("Spending Ranges (Per Student)")["Average Reading Score"].mean()
percentmathspend = schoolsummary_df.groupby("Spending Ranges (Per Student)")["% Passing Math"].mean()
percentreadspend = schoolsummary_df.groupby("Spending Ranges (Per Student)")["% Passing Reading"].mean()
percentoverallspend = schoolsummary_df.groupby("Spending Ranges (Per Student)")["% Overall Passing"].mean()

# %%
#Create dataframe to hold data
scoresbyspending_df = pd.DataFrame(
    {"Average Math Score": mathscorespend,
    "Average Reading Score": readscorespend,
    "% Passing Math": percentmathspend,
    "% Passing Reading": percentreadspend,
    "% Overall Passing": percentoverallspend})

scoresbyspending_df
# Out:
#                                Average Math Score  Average Reading Score  \
# Spending Ranges (Per Student)
# $575-$597.25                            83.455399              83.933814
# $597.25-$616.5                          83.599686              83.885211
# $616.5-$635.75                          80.199966              82.425360
# $635.75-$655                            77.866721              81.368774
#
#                                % Passing Math  % Passing Reading  \
# Spending Ranges (Per Student)
# $575-$597.25                        93.460096          96.610877
# $597.25-$616.5                      94.230858          95.900287
# $616.5-$635.75                      80.036217          89.536122
# $635.75-$655                        70.347325          82.995575
#
#                                % Overall Passing
# Spending Ranges (Per Student)
# $575-$597.25                           90.369459
# $597.25-$616.5                         90.216324
# ...

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
#Creating bins for schoolsizes
sizes = [0, 1000, 2000, 5000]
#bin names
sizelabels = ["<1000", "1000-2000","2000-5000"]

# %%
#Adding column for school sizes
schoolsummary_df["School Size"] = pd.cut(schoolsummary_df["Total Students"], bins=sizes, labels=sizelabels)

# %%
#Creating groupbys for each parameter
mathscoresize = schoolsummary_df.groupby("School Size")["Average Math Score"].mean()
readscoresize = schoolsummary_df.groupby("School Size")["Average Reading Score"].mean()
percentmathsize = schoolsummary_df.groupby("School Size")["% Passing Math"].mean()
percentreadsize = schoolsummary_df.groupby("School Size")["% Passing Reading"].mean()
percentoverallsize = schoolsummary_df.groupby("School Size")["% Overall Passing"].mean()

# %%
#Create dataframe to hold data
scoresbysize_df = pd.DataFrame(
    {"Average Math Score": mathscoresize,
    "Average Reading Score": readscoresize,
    "% Passing Math": percentmathsize,
    "% Passing Reading": percentreadsize,
    "% Overall Passing": percentoverallsize})

scoresbysize_df
# Out:
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Size
# <1000                 83.821598              83.929843       93.550225
# 1000-2000             83.374684              83.864438       93.599695
# 2000-5000             77.746417              81.344493       69.963361
#
#              % Passing Reading  % Overall Passing
# School Size
# <1000                96.099437          89.883853
# 1000-2000            96.790680          90.621535
# 2000-5000            82.766634          58.286003

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type

# %%
#Creating student count for each type of school for percent variables
studentsbytype = school_data_complete.groupby("type")["Student ID"].nunique()
studentsbytype
# Out:
# type
# Charter     12194
# District    26976
# Name: Student ID, dtype: int64

# %%
#grouping variables
ms = school_data_complete.groupby("type")["math_score"].mean()
rs = school_data_complete.groupby("type")["reading_score"].mean()
pm = school_data_complete[school_data_complete["math_score"] >= 70].groupby("type")["math_score"].count()/studentsbytype*100
pr = school_data_complete[school_data_complete["reading_score"] >= 70].groupby("type")["reading_score"].count()/studentsbytype*100
op = school_data_complete[(school_data_complete["reading_score"] >= 70) & (school_data_complete["math_score"] >= 70)].groupby("type")["student_name"].count()/studentsbytype*100

# %%
#Create dataframe to hold data
scoresbytype_df = pd.DataFrame(
    {"Average Math Score": ms,
    "Average Reading Score": rs,
    "% Passing Math": pm,
    "% Passing Reading": pr,
    "% Overall Passing": op})

scoresbytype_df
# Out:
#           Average Math Score  Average Reading Score  % Passing Math  \
# type
# Charter            83.406183              83.902821       93.701821
# District           76.987026              80.962485       66.518387
#
#           % Passing Reading  % Overall Passing
# type
# Charter           96.645891          90.560932
# District          80.905249          53.695878
